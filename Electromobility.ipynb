# %% [markdown]
# <a href="https://colab.research.google.com/github/jeberoizac/AnimalesSalvajesInvestigacion/blob/main/Electromobility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Electromobility Plus, necesita que se realice un analisis del transporte publico por zonas postales, para potenciar su campana de marketing y mejorar las ventas.

# %% [markdown]
# `#Se analiza el censo sobre el uso del trasnsporte Publico por zona postal, se toma CSV y se estrucutura en DataFrame'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('//content/drive/MyDrive/jupyterNotebook/PTS.csv')

# %%
df
# Out:
#        zip_code  public_transportation_pct  public_transportation_population
# 0          1379                        3.3                                13
# 1          1440                        0.4                                34
# 2          1505                        0.9                                23
# 3          1524                        0.5                                20
# 4          1529                        1.8                                32
# ...         ...                        ...                               ...
# 33115     61774                        0.0                                 0
# 33116     61776                        0.0                                 0
# 33117     61777                        0.0                                 0
# 33118     61816                        0.0                                 0
# 33119     61275                        1.0                                19
#
# [33120 rows x 3 columns]

# %% [markdown]
# "2 Porcentajes maximo y minimos, la columna public_transportation_pct contiene el porcentaje de poblacion por zona postal
# podemos hacer un describe o una funcion especifica para la misma columna"

# %%
df.describe()
# Out:
#            zip_code  public_transportation_pct  \
# count  33120.000000               3.312000e+04
# mean   49666.334209              -1.115137e+07
# std    27564.925769               8.549920e+07
# min      601.000000              -6.666667e+08
# 25%    26634.750000               0.000000e+00
# 50%    49739.000000               0.000000e+00
# 75%    72123.500000               1.100000e+00
# max    99929.000000               1.000000e+02
#
#        public_transportation_population
# count                      33120.000000
# mean                         230.352748
# std                         1313.382153
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                           41.000000
# max                        35139.000000

# %% [markdown]
# ##pregunta 3
# "filtrando datos, se podria eliminar datos si ahy valores 0 como en la celdas de transporte polpular o asignarles un valor promedio"
#
# <code>df_filtrado = df['public_transportation_population'].dropna(). <code>
#  >filtrar datos, como los NaN o vacios o ceros?
#
#  >luego sacar los minimos y maximos o usamos todos los valores?

# %%
#df_filtrado1 = df['public_transportation_population'].dropna()
df_filtrado1 = df['public_transportation_population'].dropna()
# Creamos la columna 'Maximo' con los mínimo de cada fila
df['Maximo'] = df.max(axis=1)

# Creamos la columna 'Minimo_10' con el 10% de los valores de 'Minimo'
df['Maximo_10%'] = df['Maximo'] * 0.1

# Mostrar el DataFrame
# Ordenar y Mostrar el DataFrame
df_sorted = df.sort_values(by='Maximo_10%', ascending=True)
df_sorted
# Out:
#        zip_code  public_transportation_pct  public_transportation_population  \
# 1380        601                        0.0                                 0
# 1343        602                        0.3                                30
# 1314        603                        0.5                                61
# 1400        606                        0.0                                 0
# 1401        610                        0.2                                20
# ...         ...                        ...                               ...
# 20572     99923               -666666666.0                                 0
# 19485     99925                        0.0                                 0
# 20571     99926                        2.3                                13
# 19450     99927                        0.0                                 0
# 20219     99929                        0.8                                 8
#
# ...

# %%
#Valores minimos
def porce(x):
  diezPo = x * 2
  return diezPo

#df["Porcentaje_X10"] = df['public_transportation_pct'].apply(porce)

poblacion_minima = df['public_transportation_pct'].min()
print(f"El porcetaje minimo de la poblacion es: {poblacion_minima}%")

# Creamos la columna 'Minimo' con los mínimo de cada fila
df['Minimo'] = df.min(axis=1)

# Creamos la columna 'Minimo_10' con el 10% de los valores de 'Minimo'
df['Minimo_10%'] = df['Minimo'] * 0.1

# Ordenar y Mostrar el DataFrame
df_sorted = df.sort_values(by='Minimo_10%', ascending=True)
df_sorted
# Out:
# El porcetaje minimo de la poblacion es: -666666666.0%
#        zip_code  public_transportation_pct  public_transportation_population  \
# 8927      28019               -666666666.0                                 0
# 11986     37246               -666666666.0                                 0
# 11985     37851               -666666666.0                                 0
# 11980     37243               -666666666.0                                 0
# 29505     87581               -666666666.0                                 0
# ...         ...                        ...                               ...
# 2932      10031                       76.9                             25530
# 2982      10026                       78.3                             15355
# 2683      11109                       81.9                              3178
# 2853      10044                       83.2                              4638
# ...

# %% [markdown]
# 4"Teniendo en cuenta donde se concentra la poblacion maxima y minima podemos hacer estimaciones, que si comprar solo el 10% de esa poblacion,1 sccoter a un valor 200mil"

# %%
#podemos crear una funcion o aplicar los porcentajes a las mismas columnas?
def porcentaje(x):
  diezPorciento = x * 0.1
  return diezPorciento

#df["VentasPorcentajede10"] = df[poblacion_minima].apply(porcentaje)

# %% [markdown]
# "#5 graficas la informacion..cual seria la info?"

# %%
#Seaborn es una librería que usamos para graficar
import seaborn as sns
#Para el grafico de barras
sns.displot(df["Minimo_10"], kind="hist")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Minimo_10'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-d39f3016e32e> in <cell line: 0>()
#       2 import seaborn as sns
#       3 #Para el grafico de barras
# ...

# %% [markdown]
# #6Agrupe a los potenciales clientes en función del uso del transporte público por código postal

# %%
#habra q hacer una funcion o una columna nueva?
